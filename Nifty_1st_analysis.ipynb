# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pd.get_option("display.max_rows")
# Out:
# 60

# %%
pd.set_option("display.max_rows",80)

# %%
data = pd.read_csv("E:\Stocks\data\\nifty_option_chain_16mar.csv")

# %%
data
# Out:
#        Call OI  Call LTP  Call Delta  Strike    IV Instrument  Put LTP  \
# 0          0.0      0.00        1.00   15800  28.8      NIFTY     0.80
# 1          0.0      0.00        1.00   15850  28.3      NIFTY     0.90
# 2          0.0      0.00        0.99   15900  27.8      NIFTY     1.00
# 3          0.0      0.00        0.99   15950  26.9      NIFTY     1.00
# 4        200.0   1415.25        0.99   16000  26.9      NIFTY     1.30
# 5          0.0      0.00        0.99   16050  26.2      NIFTY     1.40
# 6          0.0      0.00        0.99   16100  25.9      NIFTY     1.65
# 7          0.0      0.00        0.99   16150  25.4      NIFTY     1.90
# 8          0.0      0.00        0.99   16200  23.8      NIFTY     1.50
# 9          0.0      0.00        0.99   16250  23.5      NIFTY     1.85
# 10         0.0      0.00        0.99   16300  23.0      NIFTY     2.10
# 11         0.0      0.00        0.99   16350  21.6      NIFTY     1.80
# ...

# %%
data.drop('Instrument', axis=1, inplace=True)

# %%
nifty_cp = 17412

# %%
data['Call LTP'].plot()
# Out:
# <AxesSubplot: >

# %%
data[['Call LTP','Strike']].plot()
# Out:
# <AxesSubplot: >

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
data_scaled = scaler.fit_transform(data)

# %%
data_scaled[['Call LTP','Strike']].plot()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 data_scaled[['Call LTP','Strike']].plot()
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
data_sc = pd.DataFrame(data_scaled, columns=data.columns)

# %%
data_sc
# Out:
#      Call OI  Call LTP  Call Delta    Strike     IV   Put LTP  Put Delta  \
# 0   0.000000  0.000000        1.00  0.000000  0.890  0.000449       1.00
# 1   0.000000  0.000000        1.00  0.013889  0.865  0.000506       1.00
# 2   0.000000  0.000000        0.99  0.027778  0.840  0.000562       0.99
# 3   0.000000  0.000000        0.99  0.041667  0.795  0.000562       0.99
# 4   0.000020  1.000000        0.99  0.055556  0.795  0.000730       0.99
# 5   0.000000  0.000000        0.99  0.069444  0.760  0.000786       0.99
# 6   0.000000  0.000000        0.99  0.083333  0.745  0.000927       0.99
# 7   0.000000  0.000000        0.99  0.097222  0.720  0.001067       0.99
# 8   0.000000  0.000000        0.99  0.111111  0.640  0.000843       0.99
# 9   0.000000  0.000000        0.99  0.125000  0.625  0.001039       0.99
# 10  0.000000  0.000000        0.99  0.138889  0.600  0.001180       0.99
# 11  0.000000  0.000000        0.99  0.152778  0.530  0.001011       0.99
# ...

# %%
data_sc[['Call LTP','Strike']].plot()
# Out:
# <AxesSubplot: >

# %%
data.describe()
# Out:
#             Call OI     Call LTP  Call Delta        Strike         IV  \
# count  7.300000e+01    73.000000   73.000000     73.000000  73.000000
# mean   1.125734e+06   170.727397    0.446027  17600.000000  19.238356
# std    2.053121e+06   320.999055    0.447359   1060.856572   6.275827
# min    0.000000e+00     0.000000    0.000000  15800.000000  11.000000
# 25%    1.350000e+03     0.900000    0.010000  16700.000000  13.200000
# 50%    8.170000e+04     1.850000    0.230000  17600.000000  18.700000
# 75%    1.716100e+06   170.600000    0.970000  18500.000000  24.900000
# max    1.013970e+07  1415.250000    1.000000  19400.000000  31.000000
#
#            Put LTP  Put Delta        Put OI      Theta       Vega      Gamma
# count    73.000000  73.000000  7.300000e+01  73.000000  73.000000  73.000000
# mean    361.690411  -0.553973  7.927938e+05  -2.373836   2.090411   0.000318
# std     499.590950   0.447359  1.233176e+06   2.299823   2.563315   0.000468
# ...

# %%
data.plot.scatter(y = 'Call LTP', x = 'Strike', s = 50);

# %%
data.plot.scatter(y = 'Put LTP', x = 'Strike', s = 50);

# %%
data_sc.plot.scatter(y = 'Put LTP', x = 'Strike', s = 50);

# %%
data_sc.plot.scatter(y = 'Put LTP', x = 'Put Delta', s = 50);

# %%
data_sc.plot.scatter(y = 'Put LTP', x = 'Strike', s = 'Put Delta');
